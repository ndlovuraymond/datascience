# %%
# importing libraries for data manipulation and visualization
import pandas as pd

# %%
# importing Lebron's data for all major stats since 03
lebron_stats = pd.read_csv("lebron_career.csv",parse_dates=["date"])

# %%
lebron_stats.head()
# Out:
#    game       date     age team  opp   result  mp  fg  fga    fgp  ...  orb
# 0     1 2003-10-29  18-303  CLE  SAC  L (-14)  42  12   20  0.600  ...    2  \
# 1     2 2003-10-30  18-304  CLE  PHO   L (-9)  41   8   17  0.471  ...    2
# 2     3 2003-11-01  18-306  CLE  POR  L (-19)  39   3   12  0.250  ...    0
# 3     4 2003-11-05  18-310  CLE  DEN   L (-4)  41   3   11  0.273  ...    2
# 4     5 2003-11-07  18-312  CLE  IND   L (-1)  44   8   18  0.444  ...    0
#
#    drb  trb  ast  stl  blk  tov  pts  game_score  plus_minus
# 0    4    6    9    4    0    2   25        24.7          -9
# 1   10   12    8    1    0    7   21        14.7          -3
# 2    4    4    6    2    0    2    8         5.0         -21
# 3    9   11    7    2    3    2    7        11.2          -3
# 4    5    5    3    0    0    7   23         9.0          -7
#
# [5 rows x 26 columns]

# %%
lebron_2016_stats = lebron_stats[(lebron_stats.date.dt.year == 2016) & (lebron_stats.date.dt.month < 7)]

# %%
lebron_2016_stats.head()
# Out:
#      game       date     age team  opp   result  mp  fg  fga    fgp  ...  orb
# 940    30 2016-01-02  31-003  CLE  ORL  W (+25)  29  11   18  0.611  ...    0  \
# 941    31 2016-01-04  31-005  CLE  TOR  W (+22)  31   7   11  0.636  ...    0
# 942    32 2016-01-06  31-007  CLE  WAS   W (+6)  40  12   22  0.545  ...    0
# 943    33 2016-01-08  31-009  CLE  MIN  W (+26)  32   5   12  0.417  ...    0
# 944    34 2016-01-10  31-011  CLE  PHI  W (+10)  37  15   22  0.682  ...    0
#
#      drb  trb  ast  stl  blk  tov  pts  game_score  plus_minus
# 940    5    5    3    2    0    0   29        25.2          28
# 941    2    2    7    3    0    2   20        20.0          11
# 942   10   10    4    1    1    2   34        26.9           2
# 943   12   12    8    1    2    3   13        14.4          21
# 944    7    7    9    2    0    2   37        34.8          11
#
# [5 rows x 26 columns]

# %%
lbj_points = lebron_2016_stats

# %%
lbj_points.set_index('date',inplace=True)

# %%
lbj_points["outcome"] = np.where(lbj_points.result.str[:1]== 'W', 1, 0)
lbj_points.astype({"outcome": int})
# Out:
# /var/folders/7n/hf4dlwl94h97_bgxqzwrlwdr0000gn/T/ipykernel_28212/2118183472.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lbj_points["outcome"] = np.where(lbj_points.result.str[:1]== 'W', 1, 0)
#             game     age team  opp   result  mp  fg  fga    fgp  three  ...
# date                                                                    ...
# 2016-01-02    30  31-003  CLE  ORL  W (+25)  29  11   18  0.611      4  ...  \
# 2016-01-04    31  31-005  CLE  TOR  W (+22)  31   7   11  0.636      1  ...
# 2016-01-06    32  31-007  CLE  WAS   W (+6)  40  12   22  0.545      4  ...
# 2016-01-08    33  31-009  CLE  MIN  W (+26)  32   5   12  0.417      0  ...
# ...

# %%
lbj_points.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 47 entries, 2016-01-02 to 2016-04-11
# Data columns (total 43 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   game              47 non-null     int64
#  1   age               47 non-null     object
#  2   team              47 non-null     object
#  3   opp               47 non-null     object
#  4   result            47 non-null     object
#  5   mp                47 non-null     int64
#  6   fg                47 non-null     int64
#  7   fga               47 non-null     int64
#  8   fgp               47 non-null     float64
#  9   three             47 non-null     int64
#  10  threeatt          47 non-null     int64
#  11  threep            45 non-null     float64
#  12  ft                47 non-null     int64
#  13  fta               47 non-null     int64
#  14  ftp               46 non-null     float64
#  15  orb               47 non-null     int64
# ...

# %%
lbj_points["Prev Game Points"] = lbj_points["pts"].shift()
lbj_points["Prev FT"] = lbj_points["ft"].shift()
lbj_points["Prev FTA"] = lbj_points["fta"].shift()
lbj_points["Prev Three Att"] = lbj_points["threeatt"].shift()
lbj_points["Prev Three"] = lbj_points["three"].shift()
lbj_points["Prev TOV"] = lbj_points["tov"].shift()
lbj_points["Prev FG"] = lbj_points["fg"].shift()
lbj_points["Prev FGA"] = lbj_points["fga"].shift()
lbj_points["Prev STL"] = lbj_points["stl"].shift()
lbj_points["Prev BLK"] = lbj_points["blk"].shift()
lbj_points["Prev Game Score"] = lbj_points["game_score"].shift()
lbj_points["Prev Plus Minus"] = lbj_points["plus_minus"].shift()
lbj_points["Prev ORB"] = lbj_points["orb"].shift()
lbj_points["Prev DRB"] = lbj_points["drb"].shift()
lbj_points["Prev AST"] = lbj_points["ast"].shift()
lbj_points["Prev TRB"] = lbj_points["trb"].shift()
lbj_points["Prev MP"] = lbj_points["mp"].shift()
# Out:
# /var/folders/7n/hf4dlwl94h97_bgxqzwrlwdr0000gn/T/ipykernel_28212/492977080.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lbj_points["Prev Game Points"] = lbj_points["pts"].shift()
# /var/folders/7n/hf4dlwl94h97_bgxqzwrlwdr0000gn/T/ipykernel_28212/492977080.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lbj_points["Prev FT"] = lbj_points["ft"].shift()
# /var/folders/7n/hf4dlwl94h97_bgxqzwrlwdr0000gn/T/ipykernel_28212/492977080.py:3: SettingWithCopyWarning:
# ...

# %%
lbj_points["pts"].plot()
# Out:
# <Axes: xlabel='date'>

# %%
#importing more libraries
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
color_pal = ["#F8766D", "#D39200", "#93AA00", "#00BA38", "#00C19F", "#00B9E3", "#619CFF", "#DB72FB"]
_ = lbj_points["pts"].plot(style='.', figsize=(15,5), color=color_pal[0], title='points')

# %%
#splitting the data into train and test, split date is March 15 2016
split_date = '2016-03-15'
data_train = lbj_points.loc[lbj_points.index <= split_date].copy()
data_test = lbj_points.loc[lbj_points.index > split_date].copy()

# %%
data_train.head()
# Out:
#             game     age team  opp   result  mp  fg  fga    fgp  three  ...
# date                                                                    ...
# 2016-01-02    30  31-003  CLE  ORL  W (+25)  29  11   18  0.611      4  ...  \
# 2016-01-04    31  31-005  CLE  TOR  W (+22)  31   7   11  0.636      1  ...
# 2016-01-06    32  31-007  CLE  WAS   W (+6)  40  12   22  0.545      4  ...
# 2016-01-08    33  31-009  CLE  MIN  W (+26)  32   5   12  0.417      0  ...
# 2016-01-10    34  31-011  CLE  PHI  W (+10)  37  15   22  0.682      3  ...
#
#             Prev STL  Prev BLK  Prev Game Score  Prev Plus Minus  Prev ORB
# date
# 2016-01-02       NaN       NaN              NaN              NaN       NaN  \
# 2016-01-04       2.0       0.0             25.2             28.0       0.0
# 2016-01-06       3.0       0.0             20.0             11.0       0.0
# 2016-01-08       1.0       1.0             26.9              2.0       0.0
# ...

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 35 entries, 2016-01-02 to 2016-03-14
# Data columns (total 50 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   game              35 non-null     int64
#  1   age               35 non-null     object
#  2   team              35 non-null     object
#  3   opp               35 non-null     object
#  4   result            35 non-null     object
#  5   mp                35 non-null     int64
#  6   fg                35 non-null     int64
#  7   fga               35 non-null     int64
#  8   fgp               35 non-null     float64
#  9   three             35 non-null     int64
#  10  threeatt          35 non-null     int64
#  11  threep            35 non-null     float64
#  12  ft                35 non-null     int64
#  13  fta               35 non-null     int64
#  14  ftp               35 non-null     float64
#  15  orb               35 non-null     int64
# ...

# %%
data_test.head()
# Out:
#             game     age team  opp   result  mp  fg  fga    fgp  three  ...
# date                                                                    ...
# 2016-03-18    65  31-079  CLE  ORL   W (+6)  36   6   15  0.400      0  ...  \
# 2016-03-19    66  31-080  CLE  MIA  L (-21)  27  13   20  0.650      0  ...
# 2016-03-21    67  31-082  CLE  DEN  W (+33)  33  12   19  0.632      1  ...
# 2016-03-23    68  31-084  CLE  MIL   W (+9)  37   9   22  0.409      1  ...
# 2016-03-24    69  31-085  CLE  BRK   L (-9)  35  13   16  0.813      1  ...
#
#             Prev FG  Prev FGA  Prev STL  Prev BLK  Prev Game Score
# date
# 2016-03-18     10.0      20.0       1.0       0.0             18.7  \
# 2016-03-19      6.0      15.0       1.0       1.0             14.5
# 2016-03-21     13.0      20.0       1.0       0.0             17.8
# 2016-03-23     12.0      19.0       0.0       0.0             31.7
# 2016-03-24      9.0      22.0       2.0       1.0             23.1
#
# ...

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 35 entries, 2016-01-02 to 2016-03-14
# Data columns (total 51 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   game              35 non-null     int64
#  1   age               35 non-null     object
#  2   team              35 non-null     object
#  3   opp               35 non-null     object
#  4   result            35 non-null     object
#  5   mp                35 non-null     int64
#  6   fg                35 non-null     int64
#  7   fga               35 non-null     int64
#  8   fgp               35 non-null     float64
#  9   three             35 non-null     int64
#  10  threeatt          35 non-null     int64
#  11  threep            35 non-null     float64
#  12  ft                35 non-null     int64
#  13  fta               35 non-null     int64
#  14  ftp               35 non-null     float64
#  15  orb               35 non-null     int64
# ...

# %%
#function to create features for data
def create_features(df, label=None):
    df['date'] = df.index
    df["outcome"] = df["outcome"]
    df["Prev FT"] = df["Prev FT"]
    df["Prev FTA"] = df["Prev FTA"]
    df["Prev Three Att"] = df["Prev Three Att"]
    df["Prev Three"] = df["Prev Three"]
    df["Prev TOV"] = df["Prev TOV"]
    df["Prev FG"] = df["Prev FG"]
    df["Prev FGA"] = df["Prev FGA"]
    df["Prev STL"] = df["Prev STL"]
    df["Prev BLK"] = df["Prev BLK"]
    df["Prev Game Score"] = df["Prev Game Score"]
    df["Prev Plus Minus"] = df["Prev Plus Minus"]
    df["Prev ORB"] = df["Prev ORB"]
    df["Prev DRB"] = df["Prev DRB"]
    df["Prev AST"] = df["Prev AST"]
    df["Prev TRB"] = df["Prev TRB"]
    df["Prev MP"] = df["Prev MP"]
    df['hour'] = df['date'].dt.hour
    df['dayofweek'] = df['date'].dt.dayofweek
    df['quarter'] = df['date'].dt.quarter
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    df['dayofyear'] = df['date'].dt.dayofyear
    df['dayofmonth'] = df['date'].dt.day
    

    X = df[['outcome',"Prev FT","Prev FTA","Prev TRB","Prev ORB","Prev DRB","Prev TOV","Prev Plus Minus",
        "Prev FGA","Prev FG","Prev BLK","Prev STL","Prev MP","Prev Three","Prev Three Att","Prev Game Score",
            'hour','dayofweek','quarter','month','year','dayofyear','dayofmonth']]
    if label:
        y = df[label]
        return X, y
    return X

# %%
#Applying the function to my data
X_train, y_train = create_features(data_train, label='pts')
X_test, y_test = create_features(data_test, label='pts')
X_train.head()
# Out:
#             outcome  Prev FT  Prev FTA  Prev TRB  Prev ORB  Prev DRB
# date
# 2016-01-02        1      NaN       NaN       NaN       NaN       NaN  \
# 2016-01-04        1      3.0       4.0       5.0       0.0       5.0
# 2016-01-06        1      5.0       8.0       2.0       0.0       2.0
# 2016-01-08        1      6.0       8.0      10.0       0.0      10.0
# 2016-01-10        1      3.0       4.0      12.0       0.0      12.0
#
#             Prev TOV  Prev Plus Minus  Prev FGA  Prev FG  ...  Prev Three
# date                                                      ...
# 2016-01-02       NaN              NaN       NaN      NaN  ...         NaN  \
# 2016-01-04       0.0             28.0      18.0     11.0  ...         4.0
# 2016-01-06       2.0             11.0      11.0      7.0  ...         1.0
# 2016-01-08       2.0              2.0      22.0     12.0  ...         4.0
# 2016-01-10       3.0             21.0      12.0      5.0  ...         0.0
#
# ...

# %%
#importing XGBoost model
import xgboost as xgb
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
#instantiating model
reg = xgb.XGBRegressor(n_estimators=1000)

# %%
#fitting data into the model
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
import shap
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
# train XGBoost model
X,y = shap.datasets.adult()
model = xgboost.XGBClassifier().fit(X, y)

# compute SHAP values
explainer = shap.Explainer(model, X)
shap_values = explainer(X)

# %%
#checking feature important
_ = plot_importance(reg,height=0.9)

# %%
#making prediction and plotting it against everything else
data_test['points_Prediction'] = reg.predict(X_test)
data_all = pd.concat([data_test, data_train], sort=False)

# %%
#prediction plot
_ = data_all[['pts','points_Prediction']].plot(figsize=(15, 5))
