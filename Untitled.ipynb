# %%
import warnings
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

warnings.filterwarnings('ignore')
data = pd.read_csv("Lebron_data.csv")
data["Date"] = pd.to_datetime(data["Date"])
data.set_index("Date",inplace=True)
# data = data.groupby(data.index.year).mean()

# Visualize the time series data
# plt.figure(figsize=(10, 6))
# plt.plot(data)
# plt.title("Lebron Avergage Pts Per Game Per Season (Time Series Data)")
# plt.xlabel("Date")
# plt.ylabel("Points Per Game")
# plt.xticks([2005,2010,2015,2020],["2005","2010","2015","2020"])
# plt.show()
# Out:
#             pts
# Date
# 2003  20.218750
# 2004  22.565789
# 2005  29.329114
# 2006  30.262500
# 2007  27.840000
# 2008  29.550000
# 2009  28.845238
# 2010  27.710526
# 2011  28.836735
# 2012  26.586207
# 2013  26.467532
# 2014  27.052632
# 2015  25.449275
# 2016  25.250000
# 2017  27.308642
# 2018  27.225000
# 2019  26.056604
# 2020  25.542857

# %%
# Perform decomposition to identify trend and seasonality
data = pd.read_csv(
    "Lebron_data.csv"
)  # Replace 'your_data.csv' with your actual dataset filename
data["Date"] = pd.to_datetime(
    data["Date"]
)  # Convert the date column to a datetime format
data = data.asfreq('b')
decomposition = seasonal_decompose(data['Date'].values, model="additive")
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Visualize the decomposed components
plt.figure(figsize=(10, 8))
plt.subplot(411)
plt.plot(data, label="Original")
plt.legend(loc="best")
plt.subplot(412)
plt.plot(trend, label="Trend")
plt.legend(loc="best")
plt.subplot(413)
plt.plot(seasonal, label="Seasonality")
plt.legend(loc="best")
plt.subplot(414)
plt.plot(residual, label="Residuals")
plt.legend(loc="best")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [34], in <cell line: 9>()
#       5 data["Date"] = pd.to_datetime(
#       6     data["Date"]
#       7 )  # Convert the date column to a datetime format
#       8 data = data.asfreq('b')
# ----> 9 decomposition = seasonal_decompose(data['Date'].values, model="additive")
#      10 trend = decomposition.trend
#      11 seasonal = decomposition.seasonal
#
# File ~\anaconda3\lib\site-packages\statsmodels\tsa\seasonal.py:159, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     157         period = pfreq
#     158     else:
# --> 159         raise ValueError(
#     160             "You must specify a period or x must be a pandas object with "
#     161             "a PeriodIndex or a DatetimeIndex with a freq not set to None"
#     162         )
#     163 if x.shape[0] < 2 * pfreq:
# ...

# %%
# Perform Augmented Dickey-Fuller Test for stationarity
result = adfuller(data)
print("ADF Statistic:", result[0])
print("p-value:", result[1])
print("Critical Values:")
for key, value in result[4].items():
    print(f"\t{key}: {value}")

# Plot ACF and PACF to determine the order of ARIMA model
plot_acf(data, lags=20)
plt.title("Autocorrelation Function (ACF)")
plt.show()

plot_pacf(data, lags=20)
plt.title("Partial Autocorrelation Function (PACF)")
plt.show()
# Out:
# ADF Statistic: -1.5068798906632146
# p-value: 0.5301052514982608
# Critical Values:
# 	1%: -4.223238279489106
# 	5%: -3.189368925619835
# 	10%: -2.729839421487603
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [31], in <cell line: 10>()
#       7     print(f"\t{key}: {value}")
#       9 # Plot ACF and PACF to determine the order of ARIMA model
# ---> 10 plot_acf(data, lags=20)
#      11 plt.title("Autocorrelation Function (ACF)")
#      12 plt.show()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose as sm

data = pd.read_csv("Lebron_data.csv")
data["Date"] = pd.to_datetime(data["Date"])
data.set_index("Date",inplace=True)
data = data.groupby(data.index.year).mean()
T_Series = data.index.to_numpy()
Trend = data["pts"].to_numpy()
plt.plot(T_Series, Trend, 'c.')
plt.title("Trend against Time")
plt.xlabel("Year")
plt.ylabel("Points Per Game");
plt.xticks([2005,2010,2015,2020],["2005","2010","2015","2020"])
plt.show()

# %%
seasonality = 10 + np.sin(T_Series) * 10
plt.plot(seasonality)
plt.title("Seasonality against Time")
plt.xlabel("Year")
plt.ylabel("Points Per Game");
# plt.xticks([2005,2010,2015,2020],["2005","2010","2015","2020"])
seasonality
# Out:
# array([2.74119746e-01, 6.70179914e+00, 1.61618292e+01, 1.99567019e+01,
#        1.45974288e+01, 5.01130085e+00, 1.17599002e-02, 4.19536083e+00,
#        1.37157202e+01, 1.98198636e+01, 1.68956697e+01, 7.63162882e+00,
#        5.45057535e-01, 2.15131674e+00, 1.09736191e+01, 1.89007806e+01,
#        1.86446054e+01, 1.04406199e+01])

# %%
np.random.seed(10)  # for result reproducibility
residual = np.random.normal(loc=0.0, scale=1, size=len(T_Series))
plt.plot(T_Series, residual, 'r-.')
plt.title("Residuals against Time")
plt.xlabel("Minutes")
plt.ylabel("Points Per Game");
plt.xticks([2005,2010,2015,2020],["2005","2010","2015","2020"])
plt.show()

# %%
additive_Tmodel = Trend + seasonality + residual
plt.plot(T_Series, additive_Tmodel, 'k.')
plt.title("Additive Time Series")
plt.xlabel("Year")
plt.ylabel("Points Per Game");
plt.xticks([2005,2010,2015,2020],["2005","2010","2015","2020"])
plt.show()

# %%
# we ignore residual to make the pattern more apparent
ignored_residual = np.ones_like(residual)
# we multiply other components to create a multiplicative time series
multiplicative_Tmodel = Trend * seasonality * ignored_residual

# %%
plt.plot(T_Series, multiplicative_Tmodel, 'k-.')
plt.title("Multiplicative Time Series")
plt.xlabel("Year")
plt.ylabel("Points Per Game");
plt.xticks([2005,2010,2015,2020],["2005","2010","2015","2020"])
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
# frequency is the time a time serie is taking to complete on cycal
ts_dicomposition = seasonal_decompose(x=additive_Tmodel, model='additive')
trend_estimate = ts_dicomposition.trend
seasonal_estimate = ts_dicomposition.seasonal
residual_estimate = ts_dicomposition.resid
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [59], in <cell line: 3>()
#       1 from statsmodels.tsa.seasonal import seasonal_decompose
#       2 # frequency is the time a time serie is taking to complete on cycal
# ----> 3 ts_dicomposition = seasonal_decompose(x=additive_Tmodel, model='additive')
#       4 trend_estimate = ts_dicomposition.trend
#       5 seasonal_estimate = ts_dicomposition.seasonal
#
# File ~\anaconda3\lib\site-packages\statsmodels\tsa\seasonal.py:159, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     157         period = pfreq
#     158     else:
# --> 159         raise ValueError(
#     160             "You must specify a period or x must be a pandas object with "
#     161             "a PeriodIndex or a DatetimeIndex with a freq not set to None"
#     162         )
#     163 if x.shape[0] < 2 * pfreq:
# ...

# %%
pip install statsmodel
# Out:
# ERROR: Could not find a version that satisfies the requirement statsmodel (from versions: none)
# ERROR: No matching distribution found for statsmodel
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# Assuming you have a pandas DataFrame with a 'date' column and a 'value' column
# Make sure the 'date' column is of datetime type and sorted in ascending order

# Read the data into a DataFrame and set 'date' as the index
data = pd.read_csv("Lebron_data.csv")
data["Date"] = pd.to_datetime(data["Date"])
data.set_index("Date",inplace=True)

# Split the data into training and testing sets
train_data = data.iloc[-400:-164]  # Use data from 2015 onwards except the last 2 seasons for training
test_data = data.iloc[-82:]  # Last 2 years for testing

# Fit the ARIMA model
model = ARIMA(train_data["pts"], order=(25,1, 1))  # Example order, adjust as needed
model_fit = model.fit()

# Forecast 2 years ahead
forecast = model_fit.forecast(steps=82)  # Forecasting 164 games which is (2 years)
df = forecast.to_frame(name="predicted_mean")

# %%
# Create a new DataFrame for the forecasted values
forecast_dates = pd.date_range(start=test_data.index[81], periods=82, freq="5D")
forecast_df = pd.DataFrame(
    df["predicted_mean"], index=forecast_dates, columns=["forecasted_value"]
)

# Plot the actual and forecasted values
plt.plot(data.index, data["pts"], label="Actual")
plt.plot(test_data.index, df["predicted_mean"], label="Forecast")
plt.xlabel("Date")
plt.ylabel("Value")
plt.title("Time Series Forecast")
plt.legend()
plt.show()

# %%
df["predicted_mean"].max()
# Out:
# 26.589398663192522

# %%
len(test_data)
# Out:
# 164

# %%
forecast_dates = pd.Series(test_data.index)
forecast_pts = pd.Series(forecast.array,index=range(0,82))
forecast_df = pd.concat([forecast_pts.rename("pts"),forecast_dates],axis=1)
forecast_df.set_index("Date",inplace=True)
forecast_per_year = forecast_df.groupby(forecast_df.index.year).mean()
forecast_per_year
# Out:
#             pts
# Date
# 2019  27.063610
# 2020  26.925322

# %%
forecast_pts
# Out:
# 0     25.909750
# 1     29.020691
# 2     29.047189
# 3     25.215097
# 4     26.637592
#         ...
# 77    26.894483
# 78    26.922438
# 79    26.933973
# 80    26.944192
# 81    26.961829
# Length: 82, dtype: float64

# %%
forecast.array
# Out:
# <PandasArray>
# [ 25.90974965775979, 29.020691486102915,  29.04718860429771,
#   25.21509704461859,  26.63759208784528, 29.414825110977254,
#     25.426199088973, 28.704529631039186, 24.314752084353678,
#  26.962065623183356, 25.862296248320757,  27.01193386558214,
#   26.83764102042761, 25.758936866165744, 28.696815617549206,
#   28.52018416930408, 30.753913212231097, 25.898091625522632,
#  27.957344706020358, 29.151226691124243, 26.473192003961472,
#   27.94689712072231,  26.26791655425261,  25.78408912109228,
#  26.430591553621014,   28.0380787039169,  26.52973079221398,
#  26.541762537438228,  27.68665839481599,   27.1902902242242,
#  27.594151199814256, 26.750154199603806, 26.945582104090974,
#  26.378100692742688, 26.780005415895108, 26.554238871361047,
#  25.971343529659602, 26.585020854152962, 26.432365741337748,
#   27.20086835207336, 26.882489112841252, 26.730297001588475,
#  27.154338457294884, 27.203849964457554, 27.049438129996055,
# ...

# %%
forecast_dates = pd.Series([2021,2022,2023,2024,2025,2026])
forecast_dates
# Out:
# 0    2021
# 1    2022
# 2    2023
# 3    2024
# 4    2025
# 5    2026
# dtype: int64

# %%
data = pd.read_csv("Lebron_data.csv")
data["Date"] = pd.to_datetime(data["Date"])
data.set_index("Date", inplace=True)

yearly_ppg = data.groupby(data.index.year).mean()
# Split the data into training and testing sets
train_data = yearly_ppg.iloc[
    :-2
]  # Use data from 2015 onwards except the last 2 seasons for training
test_data = yearly_ppg.iloc[-2:]  # Last 2 years for testing

# Fit the ARIMA model
model = ARIMA(train_data["pts"], order=(10, 1, 1))  # Example order, adjust as needed
model_fit = model.fit()

# Forecast 2 years ahead
forecast = model_fit.forecast(steps=5)  # Forecasting 82 games which is (1 season)
df = forecast.to_frame(name="pts")

# %%
df
# Out:
#           pts
# 16  26.417437
# 17  28.605540
# 18  27.738865
# 19  27.501781
# 20  28.637416
